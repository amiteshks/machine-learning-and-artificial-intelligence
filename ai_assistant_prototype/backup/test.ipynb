# %%
print (1)
# Out:
# 1

# %%
from langgraph_workflows_manager import process_request

# %%
result = process_request("Please discharge patient 123", 1001)
# Out:
# 2025-02-24 00:01:26,859 - C:\Users\15105\MLAIBerkeleyEtc\_Qventus_POC_2025\server\langgraph_workflows_manager.py:253 - INFO - Process_request.workflow config: {'configurable': {'thread_id': 1001}}
# 2025-02-24 00:01:26,978 - C:\Users\15105\MLAIBerkeleyEtc\_Qventus_POC_2025\server\langgraph_workflows_manager.py:35 - INFO - Starting assistant_node.state: {'messages': [HumanMessage(content='Please discharge patient 123', additional_kwargs={}, response_metadata={}, id='44a7f2d8-b767-4200-ad2c-fef59fdb7a0c')]}
# ...

# %%
result

# %%
thread_id = 1001

# %%
# Second call with same thread_id
confirmation_result = process_request("yes", thread_id= thread_id)
print(f"Confirmation result: {confirmation_result}")
# Out:
# 2025-02-24 00:03:45,865 - C:\Users\15105\MLAIBerkeleyEtc\_Qventus_POC_2025\server\langgraph_workflows_manager.py:253 - INFO - Process_request.workflow config: {'configurable': {'thread_id': 1001}}
# ...
